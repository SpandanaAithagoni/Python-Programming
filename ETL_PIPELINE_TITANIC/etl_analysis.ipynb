# %%
from supabase import create_client
import pandas as pd,os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Create Supabase client
url = os.getenv("SUPABASE_URL")
key = os.getenv("SUPABASE_KEY")

if not url or not key:
    raise ValueError("Missing SUPABASE_URL or SUPABASE_KEY in .env file")

supabase = create_client(url, key)

# Fetch data
response = supabase.table("titanic_data").select("*").execute()

# Convert to DataFrame
df = pd.DataFrame(response.data)

# Display info
print(df.head())
print(df.info())
print(df.isnull().sum())
print(df.describe())
print(df.columns)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 3
#       1 from supabase import create_client
#       2 import pandas as pd,os
# ----> 3 from dotenv import load_dotenv
#       5 # Load environment variables
#       6 load_dotenv()
#
# ModuleNotFoundError: No module named 'dotenv'

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\spand\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe

# %%
# %pip install supabase python-dotenv pandas
# Out:
# Requirement already satisfied: supabase in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.25.0)
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pandas in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.3.3)
# Requirement already satisfied: realtime==2.25.0 in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from supabase) (2.25.0)
# Requirement already satisfied: supabase-functions==2.25.0 in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from supabase) (2.25.0)
# Requirement already satisfied: storage3==2.25.0 in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from supabase) (2.25.0)
# Requirement already satisfied: supabase-auth==2.25.0 in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from supabase) (2.25.0)
# Requirement already satisfied: postgrest==2.25.0 in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from supabase) (2.25.0)
# Requirement already satisfied: httpx<0.29,>=0.26 in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from supabase) (0.28.1)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from postgrest==2.25.0->supabase) (2.1.0)
# Requirement already satisfied: pydantic<3.0,>=1.9 in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from postgrest==2.25.0->supabase) (2.12.5)
# Requirement already satisfied: yarl>=1.20.1 in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from postgrest==2.25.0->supabase) (1.22.0)
# Requirement already satisfied: typing-extensions>=4.14.0 in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from realtime==2.25.0->supabase) (4.15.0)
# Requirement already satisfied: websockets<16,>=11 in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from realtime==2.25.0->supabase) (15.0.1)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pyjwt[crypto]>=2.10.1->supabase-auth==2.25.0->supabase) (2.10.1)
# Requirement already satisfied: strenum>=0.4.15 in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from supabase-functions==2.25.0->supabase) (0.4.15)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: anyio in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<0.29,>=0.26->supabase) (4.12.0)
# Requirement already satisfied: certifi in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<0.29,>=0.26->supabase) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<0.29,>=0.26->supabase) (1.0.9)
# Requirement already satisfied: idna in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<0.29,>=0.26->supabase) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore==1.*->httpx<0.29,>=0.26->supabase) (0.16.0)
# Requirement already satisfied: six>=1.5 in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: packaging in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from deprecation>=2.1.0->postgrest==2.25.0->supabase) (25.0)
# Requirement already satisfied: h2<5,>=3 in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx[http2]<0.29,>=0.26->postgrest==2.25.0->supabase) (4.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0,>=1.9->postgrest==2.25.0->supabase) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0,>=1.9->postgrest==2.25.0->supabase) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0,>=1.9->postgrest==2.25.0->supabase) (0.4.2)
# Requirement already satisfied: cryptography>=3.4.0 in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pyjwt[crypto]>=2.10.1->supabase-auth==2.25.0->supabase) (46.0.3)
# Requirement already satisfied: multidict>=4.0 in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from yarl>=1.20.1->postgrest==2.25.0->supabase) (6.7.0)
# Requirement already satisfied: propcache>=0.2.1 in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from yarl>=1.20.1->postgrest==2.25.0->supabase) (0.4.1)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->supabase-auth==2.25.0->supabase) (2.0.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==2.25.0->supabase) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==2.25.0->supabase) (4.1.0)
# Requirement already satisfied: pycparser in c:\users\spand\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->supabase-auth==2.25.0->supabase) (2.23)
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.2.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Users\spand\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\spand\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe
